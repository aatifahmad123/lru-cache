# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The number of operations in sample test case is 89*10^5.

# %%
methods = ['Approach_1_Queue','Approach_2_Deque','Approach_3_DoublyLinkedList','Approach_4_Stack','Approach_5_Counter']
average_time_taken = [8.58,8.17,7.37,12.90,3.54]

plt.figure(figsize=(10, 6))
plt.barh(methods, average_time_taken, color='skyblue')
plt.xlabel('Average Time Taken (seconds)')
plt.ylabel('Approach')
plt.title('Comparison of Average Time Taken by Different LRU Cache Implementations')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
